# %%
#libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#load the data
data = pd.read_csv('StudentsPerformance.csv')

# %%
#understanding the data
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#check uninque values in each column
data.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
#check whether have any NaN values or not?
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
#Columns 
for i in range(len(data.columns)):
    print(i+1,'. ',data.columns[i],type(data.columns[i]))
# Out:
# 1 .  gender <class 'str'>
# 2 .  race/ethnicity <class 'str'>
# 3 .  parental level of education <class 'str'>
# 4 .  lunch <class 'str'>
# 5 .  test preparation course <class 'str'>
# 6 .  math score <class 'str'>
# 7 .  reading score <class 'str'>
# 8 .  writing score <class 'str'>

# %%
def str2int(x):
    return int(x)

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# Analysis based upon gender
# Out:
# 1000

# %%
#Cleaning the dataset
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
student = data.drop(['race/ethnicity','parental level of education'], axis=1)

# %%
student.head()
# Out:
#    gender         lunch test preparation course  math score  reading score  \
# 0  female      standard                    none          72             72
# 1  female      standard               completed          69             90
# 2  female      standard                    none          90             95
# 3    male  free/reduced                    none          47             57
# 4    male      standard                    none          76             78
#
#    writing score
# 0             74
# 1             88
# 2             93
# 3             44
# 4             75

# %%
# Out:
#        math score  reading score  writing score
# count  1000.00000     1000.00000     1000.00000
# mean     66.08900       66.08900       66.08900
# std      15.16308       15.16308       15.16308
# min       0.00000        0.00000        0.00000
# 25%      57.00000       57.00000       57.00000
# 50%      66.00000       66.00000       66.00000
# 75%      77.00000       77.00000       77.00000
# max     100.00000      100.00000      100.00000

# %%
correlation = student.corr()
correlation
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,1, figsize=(20,10))
sns.heatmap(
    correlation, 
    xticklabels = correlation.columns, 
    yticklabels = correlation.columns,
    annot = True,
    ax = ax
)
ax.set_title('Heatmap of Correlation of variables ')
# Out:
# Text(0.5, 1, 'Heatmap of Correlation of variables ')

# %%
sns.pairplot(student)

# %%
sns.relplot(x ='math score', y='reading score', hue ='gender', data =student)

# %%
sns.relplot(x ='writing score', y='reading score', hue ='gender', data =student)

# %%
sns.relplot(x ='writing score', y='reading score', hue ='test preparation course', data =student)

# %%
sns.distplot(student['math score'])
# Out:
# C:\Users\PEEKAY MURMU\Anaconda3\envs\deeplearning\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(student['writing score'])
# Out:
# C:\Users\PEEKAY MURMU\Anaconda3\envs\deeplearning\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(student['reading score'], bins=10)
# Out:
# C:\Users\PEEKAY MURMU\Anaconda3\envs\deeplearning\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.catplot(x ='reading score', kind='box', data = student)

# %%
sns.catplot(x ='writing score', kind='box', data = student)

# %%
sns.catplot(x ='math score', kind='box', data = student)

# %%
groupbygender = data.groupby('gender')

# %%
groupbygender.get_group('male').describe()
# Out:
#        math score  reading score  writing score
# count  482.000000     482.000000     482.000000
# mean    68.728216      65.473029      63.311203
# std     14.356277      13.931832      14.113832
# min     27.000000      23.000000      15.000000
# 25%     59.000000      56.000000      53.000000
# 50%     69.000000      66.000000      64.000000
# 75%     79.000000      75.000000      73.750000
# max    100.000000     100.000000     100.000000

# %%
groupbygender.get_group('female').describe()
# Out:
#        math score  reading score  writing score
# count  518.000000     518.000000     518.000000
# mean    63.633205      72.608108      72.467181
# std     15.491453      14.378245      14.844842
# min      0.000000      17.000000      10.000000
# 25%     54.000000      63.250000      64.000000
# 50%     65.000000      73.000000      74.000000
# 75%     74.000000      83.000000      82.000000
# max    100.000000     100.000000     100.000000
